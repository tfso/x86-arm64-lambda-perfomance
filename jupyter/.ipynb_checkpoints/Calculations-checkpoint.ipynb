# %%
testname="fib"

# %%
import pandas as pd
import json
def convert(x,y,z):
    name = x+str(y)
    temp = pd.DataFrame(z)
    temp.rename(columns = {'duration':name+'duration', 'billed':name+'billed', 'memoryUsed':name+'memory_used'},inplace = True)
    temp["id"]=tuple(range(1, 101, 1))
    return temp
original = pd.read_json('../results/'+testname+'.json')
result = [convert(x, y,z) for x, y,z in zip(original['architecture'], original['memory'],original['testResult'])]
dfs = [df.set_index('id') for df in result]
converted = pd.concat(dfs,axis=1)
converted
# Out:
#      ARM1024duration  ARM1024billed  ARM1024memory_used  ARM128duration  \
# id
# 1            1012.21           1013                  61         8180.32
# 2            1004.07           1005                  61         8001.76
# 3             996.51            997                  61         7994.02
# 4            1003.95           1004                  61         7996.99
# 5            1005.07           1006                  61         7999.94
# ..               ...            ...                 ...             ...
# 96            994.39            995                  65         7965.74
# 97            992.87            993                  65         7993.34
# 98            988.45            989                  65         8019.05
# 99            991.33            992                  65         7947.02
# 100           988.70            989                  65         7954.23
#
#      ARM128billed  ARM128memory_used  ARM256duration  ARM256billed  \
# id
# 1            8181                 61         4062.35          4063
# 2            8002                 62         4030.42          4031
# 3            7995                 62         4010.30          4011
# 4            7997                 62         4033.11          4034
# 5            8000                 62         4026.37          4027
# ..            ...                ...             ...           ...
# 96           7966                 65         4007.21          4008
# 97           7994                 65         4021.76          4022
# 98           8020                 65         4015.12          4016
# 99           7948                 65         4015.33          4016
# 100          7955                 65         4014.91          4015
#
#      ARM256memory_used  ARM512duration  ...  x861024memory_used  \
# id                                      ...
# 1                   61         2044.98  ...                  63
# 2                   61         2009.35  ...                  64
# 3                   61         2014.89  ...                  64
# 4                   61         2009.43  ...                  64
# 5                   61         2024.41  ...                  64
# ..                 ...             ...  ...                 ...
# 96                  65         1988.98  ...                  68
# 97                  65         2008.88  ...                  68
# 98                  65         1996.17  ...                  68
# 99                  65         2007.68  ...                  68
# 100                 65         2009.35  ...                  68
#
#      x86128duration  x86128billed  x86128memory_used  x86256duration  \
# id
# 1           9028.89          9029                 63         4463.71
# 2           8953.65          8954                 64         4470.43
# 3           8951.19          8952                 64         4478.25
# 4           8949.25          8950                 64         4465.84
# 5           8910.58          8911                 64         4466.74
# ..              ...           ...                ...             ...
# 96          8888.62          8889                 67         4429.57
# 97          8900.34          8901                 67         4436.58
# 98          8909.68          8910                 67         4431.01
# 99          8913.52          8914                 67         4419.21
# 100         8903.31          8904                 67         4426.77
#
#      x86256billed  x86256memory_used  x86512duration  x86512billed  \
# id
# 1            4464                 63         1647.09          1648
# 2            4471                 64         1592.88          1593
# 3            4479                 64         1592.09          1593
# 4            4466                 64         1591.05          1592
# 5            4467                 64         1587.70          1588
# ..            ...                ...             ...           ...
# 96           4430                 68         1587.17          1588
# 97           4437                 68         1579.40          1580
# 98           4432                 68         1581.02          1582
# 99           4420                 68         1587.36          1588
# 100          4427                 68         1575.30          1576
#
#      x86512memory_used
# id
# 1                   64
# 2                   64
# 3                   64
# 4                   64
# 5                   64
# ..                 ...
# 96                  67
# 97                  67
# 98                  67
# 99                  67
# 100                 67
#
# [100 rows x 24 columns]

# %%
converted.mean()
# Out:
# ARM1024duration        995.3245
# ARM1024billed          995.8300
# ARM1024memory_used      63.7100
# ARM128duration        7965.3700
# ARM128billed          7965.8800
# ARM128memory_used       63.8100
# ARM256duration        4021.7061
# ARM256billed          4022.2200
# ARM256memory_used       63.7100
# ARM512duration        2008.7476
# ARM512billed          2009.2600
# ARM512memory_used       63.9100
# x861024duration       1115.8806
# x861024billed         1116.3900
# x861024memory_used      66.2700
# x86128duration        8920.1566
# x86128billed          8920.6500
# x86128memory_used       65.8700
# x86256duration        4442.5843
# x86256billed          4443.1300
# x86256memory_used       66.1800
# x86512duration        1585.5860
# x86512billed          1586.1000
# x86512memory_used       65.8700
# dtype: float64
